# %%
#kütüphaneleri içeri aktarıyoruz
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl

# %%
insurance=pd.read_csv("insurance.csv")
df=insurance.copy()
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df['smoker']=df['smoker'].astype('category')

# %%
df["smoker"]
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: category
# Categories (2, object): ['no', 'yes']

# %%
df["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
#elimizdeki verilere bakıyoruz

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
#şimdi cinsiyet sigara ve bölge verilerini kategorik hale getireceğiz.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df.smoker.drop_duplicates())
df.smoker = le.transform(df.smoker)
le.fit(df.region.drop_duplicates())
df.region = le.transform(df.region)
le.fit(df.sex.drop_duplicates())
df.sex = le.transform(df.sex)

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#verileri anlamak için histogram çiziyoruz
insurance.hist(bins=60, figsize=(10, 5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-79e4e73e41da> in <cell line: 3>()
#       1 #verileri anlamak için histogram çiziyoruz
#       2 insurance.hist(bins=60, figsize=(10, 5))
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.boxplot(x="charges",data=df)
# Out:
# <Axes: xlabel='charges'>

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(insurance, test_size=0.2, random_state=42)

# %%
train_set.head()
# Out:
#       age     sex    bmi  children smoker     region      charges
# 560    46  female  19.95         2     no  northwest   9193.83850
# 1285   47  female  24.32         0     no  northeast   8534.67180
# 1142   52  female  24.86         0     no  southeast  27117.99378
# 969    39  female  34.32         5     no  southeast   8596.82780
# 486    54  female  21.47         3     no  northwest  12475.35130

# %%
corr_mat = train_set.corr(numeric_only=True)
corr_mat
# Out:
#                age       bmi  children   charges
# age       1.000000  0.118274  0.060999  0.281721
# bmi       0.118274  1.000000 -0.005040  0.197316
# children  0.060999 -0.005040  1.000000  0.071885
# charges   0.281721  0.197316  0.071885  1.000000

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', data=df)

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', data=df[(df.age == 18)])
pl.title("18 yaşındaki sigara içen ve içmeyen bireyler")
# Out:
# Text(0.5, 1.0, '18 yaşındaki sigara içen ve içmeyen bireyler')

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(train_set, figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='bmi', ylabel='age'>,
#         <Axes: xlabel='children', ylabel='age'>,
#         <Axes: xlabel='charges', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='bmi'>,
#         <Axes: xlabel='bmi', ylabel='bmi'>,
#         <Axes: xlabel='children', ylabel='bmi'>,
#         <Axes: xlabel='charges', ylabel='bmi'>],
#        [<Axes: xlabel='age', ylabel='children'>,
#         <Axes: xlabel='bmi', ylabel='children'>,
#         <Axes: xlabel='children', ylabel='children'>,
#         <Axes: xlabel='charges', ylabel='children'>],
#        [<Axes: xlabel='age', ylabel='charges'>,
#         <Axes: xlabel='bmi', ylabel='charges'>,
#         <Axes: xlabel='children', ylabel='charges'>,
#         <Axes: xlabel='charges', ylabel='charges'>]], dtype=object)
